# %% [markdown]
# # Preprocessing personalized and self coded tools and Animation Module (TESTS)

# %% [markdown]
# ### body, head, arm detector and landmarker.
# library used opencv (for camera,frame), mediapipe(a very well written DL model)

# %%
import cv2
import mediapipe as mp
import csv
import time


mp_holistic = mp.solutions.holistic
holistic = mp_holistic.Holistic(static_image_mode=True, 
                                model_complexity=2, 
                                min_detection_confidence=0.5, 
                                min_tracking_confidence=0.5)


cap = cv2.VideoCapture(0)  


landmark_data = []


fps_start_time = time.time()
fps_counter = 0
fps = 0
key_face_landmarks_indices = [1, 33, 263, 61, 291, 199]

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
  
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    #holistic DL model prediction
    results = holistic.process(rgb_frame)
    

    #result to landmark array insersion
    frame_landmarks = {}
    
    if results.pose_landmarks:
        frame_landmarks['pose'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.pose_landmarks.landmark]
    
    if results.face_landmarks:
        # Filter and store only the key face landmarks based on the selected indices
        frame_landmarks['face'] = [(landmark.x, landmark.y, landmark.z) for idx, landmark in enumerate(results.face_landmarks.landmark) if idx in key_face_landmarks_indices]
    
    if results.left_hand_landmarks:
        frame_landmarks['left_hand'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.left_hand_landmarks.landmark]
    
    if results.right_hand_landmarks:
        frame_landmarks['right_hand'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.right_hand_landmarks.landmark]
    
    landmark_data.append(frame_landmarks)
    
    #result landmark to screen draw the points 
    if results.pose_landmarks:
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            cx, cy = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0])
            cv2.circle(frame, (cx, cy), 3, (0, 255, 0), -1)
    
    if results.face_landmarks:
        for idx, landmark in enumerate(results.face_landmarks.landmark):
            # Only draw key face landmarks
            if idx in key_face_landmarks_indices:
                cx, cy = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0])
                cv2.circle(frame, (cx, cy), 2, (255, 0, 0), -1)
    
    if results.left_hand_landmarks:
        for idx, landmark in enumerate(results.left_hand_landmarks.landmark):
            cx, cy = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0])
            cv2.circle(frame, (cx, cy), 3, (0, 0, 255), -1)
    
    if results.right_hand_landmarks:
        for idx, landmark in enumerate(results.right_hand_landmarks.landmark):
            cx, cy = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0])
            cv2.circle(frame, (cx, cy), 3, (0, 0, 255), -1)
    
    # Calculate FPS
    fps_counter += 1
    if fps_counter >= 10:  # Update FPS every 10 frames
        fps_end_time = time.time()
        fps = int(fps_counter / (fps_end_time - fps_start_time))
        fps_counter = 0
        fps_start_time = fps_end_time
    
    
    cv2.putText(frame, f"FPS: {fps}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    
    cv2.imshow('kyamara', frame)
    
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# after the completetion of  the landmark array will be written to  csv
with open('landmark_data.csv', 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    header = ['frame', 'type', 'index', 'x', 'y', 'z']
    csvwriter.writerow(header)
    
    for frame_index, frame_data in enumerate(landmark_data):
        for landmark_type, landmarks in frame_data.items():
            for idx, (x, y, z) in enumerate(landmarks):
                csvwriter.writerow([frame_index, landmark_type, idx, x, y, z])


cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# comment: serious FPS problems, tensorflow 2.10 above wont take gpu.
# utilize tensorfolow 2.10 or below library, tensor-gpu , and dont forget to check entire dependency versions before even beginning

# %% [markdown]
# ### (ALL Video on clip folder process TO Landmarks on csv folder)

# %%
import os
import cv2
import mediapipe as mp
import csv
import time


mp_holistic = mp.solutions.holistic
holistic = mp_holistic.Holistic(static_image_mode=False, 
                                model_complexity=2, 
                                min_detection_confidence=0.5, 
                                min_tracking_confidence=0.5)


clips_folder = './clips/'


csv_folder = './csv_files/'


os.makedirs(csv_folder, exist_ok=True)


def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    landmark_data = []
    
    
    fps_start_time = time.time()
    fps_counter = 0
    fps = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        
        results = holistic.process(rgb_frame)
        
        
        frame_landmarks = {}
        if results.pose_landmarks:
            frame_landmarks['pose'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.pose_landmarks.landmark]
        if results.face_landmarks:
            frame_landmarks['face'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.face_landmarks.landmark]
        if results.left_hand_landmarks:
            frame_landmarks['left_hand'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.left_hand_landmarks.landmark]
        if results.right_hand_landmarks:
            frame_landmarks['right_hand'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.right_hand_landmarks.landmark]
        
        landmark_data.append(frame_landmarks)
        

        fps_counter += 1
        if fps_counter >= 10:  
            fps_end_time = time.time()
            fps = int(fps_counter / (fps_end_time - fps_start_time))
            fps_counter = 0
            fps_start_time = fps_end_time
        
    
        cv2.putText(frame, f"FPS: {fps}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
    
        cv2.imshow('Frame', frame)
        
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    
    cap.release()
    cv2.destroyAllWindows()
    
    return landmark_data


for folder in os.listdir(clips_folder):
    folder_path = os.path.join(clips_folder, folder)
    
    
    if os.path.isdir(folder_path):
        video_file = os.path.join(folder_path, f"{folder}.mp4")
        
        
        if os.path.exists(video_file):
            print(f"Processing {video_file}...")
            
            
            landmark_data = process_video(video_file)
            
            
            csv_file = os.path.join(csv_folder, f"{folder}.csv")
            with open(csv_file, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                header = ['frame', 'type', 'index', 'x', 'y', 'z']
                csvwriter.writerow(header)
                
                for frame_index, frame_data in enumerate(landmark_data):
                    for landmark_type, landmarks in frame_data.items():
                        for idx, (x, y, z) in enumerate(landmarks):
                            csvwriter.writerow([frame_index, landmark_type, idx, x, y, z])
            
            print(f"CSV file {folder}.csv created.")
        else:
            print(f"No video file found for {folder}.")
    else:
        print(f"{folder} is not a directory.")

print("Processing completed.")

# %% [markdown]
# ### Landmark CSv animation by input and folder scan(looped)

# %%
import cv2
import numpy as np
import csv
import os

#  read landmark data from CSV file
def read_landmark_data(csv_file):
    landmark_data = {}
    with open(csv_file, 'r') as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader)  
        for row in csvreader:
            frame = int(row[0])
            landmark_type = row[1]
            index = int(row[2])
            x, y, z = float(row[3]), float(row[4]), float(row[5])
            if frame not in landmark_data:
                landmark_data[frame] = {'pose': [], 'face': [], 'left_hand': [], 'right_hand': []}
            landmark_data[frame][landmark_type].append((x, y, z))
    return landmark_data

#  landmarks and connections with colors
def draw_landmarks(img, landmarks, connections, color):
    for (i, j) in connections:
        if i < len(landmarks) and j < len(landmarks):
            pt1 = (int(landmarks[i][0] * img.shape[1]), int(landmarks[i][1] * img.shape[0]))
            pt2 = (int(landmarks[j][0] * img.shape[1]), int(landmarks[j][1] * img.shape[0]))
            cv2.line(img, pt1, pt2, color, 2)
    for (x, y, z) in landmarks:
        cv2.circle(img, (int(x * img.shape[1]), int(y * img.shape[0])), 3, color, -1)

#  connections for pose and hand landmarks
pose_connections = [
    (0, 1), (1, 2), (2, 3), (3, 7), (0, 4), (4, 5), (5, 6), (6, 8),  # Torso and arms
    (9, 10), (11, 12), (11, 13), (13, 15), (15, 17), (12, 14), (14, 16)  # Legs
]

hand_connections = [
    (0, 1), (1, 2), (2, 3), (3, 4),  # Thumb
    (0, 5), (5, 6), (6, 7), (7, 8),  # Index finger
    (0, 9), (9, 10), (10, 11), (11, 12),  # Middle finger
    (0, 13), (13, 14), (14, 15), (15, 16),  # Ring finger
    (0, 17), (17, 18), (18, 19), (19, 20)  # Pinky finger
]


pose_color = (0, 255, 0)  
hand_color = (0, 0, 255)  

# Function to display standing still body animation with colors
def display_standing_body(img):
    # pose landmarks
    draw_landmarks(img, [], pose_connections, pose_color)
    #  hand landmarks
    draw_landmarks(img, [], hand_connections, hand_color)

# Function to display animation based on CSV file
def display_animation(word):
    csv_file = get_csv_file(word)
    if os.path.exists(csv_file):
        landmark_data = read_landmark_data(csv_file)
        for frame_index in sorted(landmark_data.keys()):
            frame_landmarks = landmark_data[frame_index]
            img = np.zeros((720, 1280, 3), dtype=np.uint8)  # Create a black image

            if 'pose' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['pose'], pose_connections, pose_color)
            if 'face' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['face'], [], (255, 0, 0))  # Blue for face (if needed)
            if 'left_hand' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['left_hand'], hand_connections, hand_color)
            if 'right_hand' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['right_hand'], hand_connections, hand_color)

            cv2.imshow('Stickman Animation', img)
            if cv2.waitKey(50) & 0xFF == ord('q'):
                break
        cv2.destroyAllWindows()
    else:
        print(f'Animation for "{word}" not found.')

# Function to get CSV file path based on user input
def get_csv_file(word):
    return f'./csv_files/{word.lower()}.csv'

# Main function to continuously prompt for input and display animations
def main():
    standing_body = np.zeros((720, 1280, 3), dtype=np.uint8)  # Initial standing still body image
    display_standing_body(standing_body)

    while True:
        word = input("Enter a word to animate (or press Enter to show standing still body, q to quit): ").strip().lower()
        if word == 'q':
            break
        if word:
            display_animation(word)
            display_standing_body(standing_body)

    cv2.destroyAllWindows()

# Start the program
if __name__ == "__main__":
    main()
# Out:
# Enter a word to animate (or press Enter to show standing still body, q to quit):  aama

# %% [markdown]
# ### continous String Animation

# %%
import cv2
import numpy as np
import csv
import os

# Read landmark data from CSV file
def read_landmark_data(csv_file):
    landmark_data = {}
    with open(csv_file, 'r') as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader)  # Skip header
        for row in csvreader:
            frame = int(row[0])
            landmark_type = row[1]
            index = int(row[2])
            x, y, z = float(row[3]), float(row[4]), float(row[5])
            if frame not in landmark_data:
                landmark_data[frame] = {'pose': [], 'face': [], 'left_hand': [], 'right_hand': []}
            landmark_data[frame][landmark_type].append((x, y, z))
    return landmark_data

# Draw landmarks and connections with colors
def draw_landmarks(img, landmarks, connections, color):
    for (i, j) in connections:
        if i < len(landmarks) and j < len(landmarks):
            pt1 = (int(landmarks[i][0] * img.shape[1]), int(landmarks[i][1] * img.shape[0]))
            pt2 = (int(landmarks[j][0] * img.shape[1]), int(landmarks[j][1] * img.shape[0]))
            cv2.line(img, pt1, pt2, color, 2)
    for (x, y, z) in landmarks:
        cv2.circle(img, (int(x * img.shape[1]), int(y * img.shape[0])), 3, color, -1)

# Connections for pose and hand landmarks
pose_connections = [
    (0, 1), (1, 2), (2, 3), (3, 7), (0, 4), (4, 5), (5, 6), (6, 8),  # Torso and arms
    (9, 10), (11, 12), (11, 13), (13, 15), (15, 17), (12, 14), (14, 16)  # Legs
]

hand_connections = [
    (0, 1), (1, 2), (2, 3), (3, 4),  # Thumb
    (0, 5), (5, 6), (6, 7), (7, 8),  # Index finger
    (0, 9), (9, 10), (10, 11), (11, 12),  # Middle finger
    (0, 13), (13, 14), (14, 15), (15, 16),  # Ring finger
    (0, 17), (17, 18), (18, 19), (19, 20)  # Pinky finger
]

pose_color = (0, 255, 0)  # Green for pose
hand_color = (0, 0, 255)  # Red for hands

# Function to display standing still body animation with colors
def display_standing_body(img):
    # Draw pose and hand landmarks on the image
    draw_landmarks(img, [], pose_connections, pose_color)  # Draw pose landmarks
    draw_landmarks(img, [], hand_connections, hand_color)  # Draw hand landmarks

# Function to display animation based on CSV file
def display_animation(word):
    csv_file = get_csv_file(word)
    if os.path.exists(csv_file):
        landmark_data = read_landmark_data(csv_file)
        for frame_index in sorted(landmark_data.keys()):
            frame_landmarks = landmark_data[frame_index]
            img = np.zeros((720, 1280, 3), dtype=np.uint8)  # Create a black image

            # Draw pose landmarks if available
            if 'pose' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['pose'], pose_connections, pose_color)

            # Draw face landmarks if available
            if 'face' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['face'], [], (255, 0, 0))  # Blue for face (if needed)

            # Draw left hand landmarks if available
            if 'left_hand' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['left_hand'], hand_connections, hand_color)

            # Draw right hand landmarks if available
            if 'right_hand' in frame_landmarks:
                draw_landmarks(img, frame_landmarks['right_hand'], hand_connections, hand_color)

            # Display the image with animation
            cv2.imshow('Stickman Animation', img)
            if cv2.waitKey(50) & 0xFF == ord('q'):
                break
        cv2.destroyAllWindows()
    else:
        print(f'Animation for "{word}" not found.')

# Function to get CSV file path based on user input
def get_csv_file(word):
    return f'./csv_files/{word.lower()}.csv'

# Main function to continuously prompt for input and display animations
def main():
    standing_body = np.zeros((720, 1280, 3), dtype=np.uint8)  # Initial standing still body image
    display_standing_body(standing_body)

    while True:
        input_string = input("Enter words (separated by spaces) to animate, or press Enter to show standing still body, or 'q' to quit: ").strip().lower()
        if input_string == 'q':
            break
        if input_string:
            words = input_string.split()
            for word in words:
                display_animation(word)
                display_standing_body(standing_body)

    cv2.destroyAllWindows()

# Start the program
if __name__ == "__main__":
    main()
# Out:
# Enter words (separated by spaces) to animate, or press Enter to show standing still body, or 'q' to quit:  aama
# Enter words (separated by spaces) to animate, or press Enter to show standing still body, or 'q' to quit:  q

# %% [markdown]
# ### Landmark CSV to animation (word to animation).
# the word with its already data on the db, will utilize it directly. just we need to pass the word to search the db for its landmark positions data.
# comment: dont forget to check dependency versions T_T

# %%
import csv
import cv2
import numpy as np

# Function to read landmark data from CSV file
def read_landmark_data(csv_file):
    landmark_data = {}
    with open(csv_file, 'r') as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader)  
        for row in csvreader:
            frame = int(row[0])
            landmark_type = row[1]
            index = int(row[2])
            x, y, z = float(row[3]), float(row[4]), float(row[5])
            if frame not in landmark_data:
                landmark_data[frame] = {'pose': [], 'face': [], 'left_hand': [], 'right_hand': []}
            landmark_data[frame][landmark_type].append((x, y, z))
    return landmark_data

# Function to draw landmarks and connections
def draw_landmarks(img, landmarks, connections, color):
    for (i, j) in connections:
        if i < len(landmarks) and j < len(landmarks):
            pt1 = (int(landmarks[i][0] * img.shape[1]), int(landmarks[i][1] * img.shape[0]))
            pt2 = (int(landmarks[j][0] * img.shape[1]), int(landmarks[j][1] * img.shape[0]))
            cv2.line(img, pt1, pt2, color, 2)
    for (x, y, z) in landmarks:
        cv2.circle(img, (int(x * img.shape[1]), int(y * img.shape[0])), 3, color, -1)

# landmarks nodes to be seen as connected or drawn but not written
pose_connections = [
    (0, 1), (1, 2), (2, 3), (3, 7), (0, 4), (4, 5), (5, 6), (6, 8),  # Torso and arms
    (9, 10), (11, 12), (11, 13), (13, 15), (15, 17), (12, 14), (14, 16)  # Legs
]


hand_connections = [
    (0, 1), (1, 2), (2, 3), (3, 4),  # Thumb
    (0, 5), (5, 6), (6, 7), (7, 8),  # Index finger
    (0, 9), (9, 10), (10, 11), (11, 12),  # Middle finger
    (0, 13), (13, 14), (14, 15), (15, 16),  # Ring finger
    (0, 17), (17, 18), (18, 19), (19, 20)  # Pinky finger
]


landmark_data = read_landmark_data('landmark_data.csv')


for frame_index in sorted(landmark_data.keys()):
    frame_landmarks = landmark_data[frame_index]
    img = np.zeros((720, 1280, 3), dtype=np.uint8)

    if 'pose' in frame_landmarks:
        draw_landmarks(img, frame_landmarks['pose'], pose_connections, (0, 255, 0))
    if 'face' in frame_landmarks:
        draw_landmarks(img, frame_landmarks['face'], [], (255, 0, 0))  
    if 'left_hand' in frame_landmarks:
        draw_landmarks(img, frame_landmarks['left_hand'], hand_connections, (0, 0, 255))
    if 'right_hand' in frame_landmarks:
        draw_landmarks(img, frame_landmarks['right_hand'], hand_connections, (0, 0, 255))

    cv2.imshow('Stickman Animation', img)
    if cv2.waitKey(50) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

# %% [markdown]
# ### MP4 to CSV files version 2.0 (Final Version)

# %%
import os
import cv2
import mediapipe as mp
import csv
import time



mp_holistic = mp.solutions.holistic
holistic = mp_holistic.Holistic(static_image_mode=False, 
                                model_complexity=2, 
                                min_detection_confidence=0.5, 
                                min_tracking_confidence=0.5)


key_face_landmarks_indices = [1, 33, 263, 61, 291, 199]

input_folder = './myHero/'


output_folder = './SignsCsv/'


os.makedirs(csv_folder, exist_ok=True)


def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    landmark_data = []
    
    
    fps_start_time = time.time()
    fps_counter = 0
    fps = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        
        results = holistic.process(rgb_frame)
        
        
        frame_landmarks = {}
        if results.pose_landmarks:
            frame_landmarks['pose'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.pose_landmarks.landmark]
        if results.face_landmarks:
            frame_landmarks['face'] = [(landmark.x, landmark.y, landmark.z) for idx, landmark in enumerate(results.face_landmarks.landmark) if idx in key_face_landmarks_indices]
        if results.left_hand_landmarks:
            frame_landmarks['left_hand'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.left_hand_landmarks.landmark]
        if results.right_hand_landmarks:
            frame_landmarks['right_hand'] = [(landmark.x, landmark.y, landmark.z) for landmark in results.right_hand_landmarks.landmark]
        
        landmark_data.append(frame_landmarks)
        
    
        fps_counter += 1
        if fps_counter >= 10:  
            fps_end_time = time.time()
            fps = int(fps_counter / (fps_end_time - fps_start_time))
            fps_counter = 0
            fps_start_time = fps_end_time
        
    
        cv2.putText(frame, f"FPS: {fps}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
    
        cv2.imshow('Frame', frame)
        
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    
    cap.release()
    cv2.destroyAllWindows()
    
    return landmark_data




for root, dirs, files in os.walk(input_folder):
    
    if root != input_folder:  
        
        relative_path = os.path.relpath(root, input_folder)
        
        
        output_subfolder = os.path.join(output_folder, relative_path)
        os.makedirs(output_subfolder, exist_ok=True)  

        
        folder_name = os.path.basename(root)

        
        counter = 1

        
        for file in files:
            if file.endswith('.mp4'):  
                video_file = os.path.join(root, file)
                print(f"Processing {video_file}...")

                
                landmark_data = process_video(video_file)

                
                csv_filename = f"{folder_name}{counter}.csv"

                
                csv_file = os.path.join(output_subfolder, csv_filename)

                
                with open(csv_file, 'w', newline='') as csvfile:
                    csvwriter = csv.writer(csvfile)
                    header = ['frame', 'type', 'index', 'x', 'y', 'z']
                    csvwriter.writerow(header)

                    for frame_index, frame_data in enumerate(landmark_data):
                        for landmark_type, landmarks in frame_data.items():
                            for idx, (x, y, z) in enumerate(landmarks):
                                csvwriter.writerow([frame_index, landmark_type, idx, x, y, z])

                print(f"CSV file {csv_filename} created in {output_subfolder}.")

                
                counter += 1

        print(f"Finished processing folder: {relative_path}")

print("Processing completed.")
# Out:
# Processing ./myHero/Achamma\WIN_20241112_17_54_57_Pro.mp4...
# CSV file Achamma1.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_55_02_Pro.mp4...
# CSV file Achamma2.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_55_17_Pro.mp4...
# CSV file Achamma3.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_55_30_Pro.mp4...
# CSV file Achamma4.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_55_38_Pro.mp4...
# CSV file Achamma5.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_55_42_Pro.mp4...
# CSV file Achamma6.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_56_25_Pro.mp4...
# CSV file Achamma7.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_56_30_Pro.mp4...
# CSV file Achamma8.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_56_38_Pro.mp4...
# CSV file Achamma9.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_56_52_Pro.mp4...
# CSV file Achamma10.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_57_05_Pro.mp4...
# CSV file Achamma11.csv created in ./SignsCsv/Achamma.
# Processing ./myHero/Achamma\WIN_20241112_17_57_14_Pro.mp4...
# CSV file Achamma12.csv created in ./SignsCsv/Achamma.
# Finished processing folder: Achamma
# Processing ./myHero/Alchi\WIN_20241030_19_25_28_Pro.mp4...
# CSV file Alchi1.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_27_14_Pro.mp4...
# CSV file Alchi2.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_28_09_Pro.mp4...
# CSV file Alchi3.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_28_50_Pro.mp4...
# CSV file Alchi4.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_28_58_Pro.mp4...
# CSV file Alchi5.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_29_05_Pro.mp4...
# CSV file Alchi6.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_29_12_Pro.mp4...
# CSV file Alchi7.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_29_17_Pro.mp4...
# CSV file Alchi8.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_29_24_Pro.mp4...
# CSV file Alchi9.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_29_40_Pro.mp4...
# CSV file Alchi10.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_29_50_Pro.mp4...
# CSV file Alchi11.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_29_59_Pro.mp4...
# CSV file Alchi12.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_30_09_Pro.mp4...
# CSV file Alchi13.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_30_20_Pro.mp4...
# CSV file Alchi14.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_30_35_Pro.mp4...
# CSV file Alchi15.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_30_43_Pro.mp4...
# CSV file Alchi16.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_30_52_Pro.mp4...
# CSV file Alchi17.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_30_59_Pro.mp4...
# CSV file Alchi18.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_31_16_Pro.mp4...
# CSV file Alchi19.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_31_23_Pro.mp4...
# CSV file Alchi20.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_31_31_Pro.mp4...
# CSV file Alchi21.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_31_39_Pro.mp4...
# CSV file Alchi22.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_31_54_Pro.mp4...
# CSV file Alchi23.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_02_Pro.mp4...
# CSV file Alchi24.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_09_Pro.mp4...
# CSV file Alchi25.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_17_Pro.mp4...
# CSV file Alchi26.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_23_Pro.mp4...
# CSV file Alchi27.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_30_Pro.mp4...
# CSV file Alchi28.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_38_Pro.mp4...
# CSV file Alchi29.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_52_Pro.mp4...
# CSV file Alchi30.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_32_58_Pro.mp4...
# CSV file Alchi31.csv created in ./SignsCsv/Alchi.
# Processing ./myHero/Alchi\WIN_20241030_19_33_06_Pro.mp4...
# CSV file Alchi32.csv created in ./SignsCsv/Alchi.
# Finished processing folder: Alchi
# Processing ./myHero/Bar\WIN_20241112_17_44_35_Pro.mp4...
# CSV file Bar1.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_44_40_Pro.mp4...
# CSV file Bar2.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_44_50_Pro.mp4...
# CSV file Bar3.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_44_55_Pro.mp4...
# CSV file Bar4.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_01_Pro.mp4...
# CSV file Bar5.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_06_Pro.mp4...
# CSV file Bar6.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_11_Pro.mp4...
# CSV file Bar7.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_16_Pro.mp4...
# CSV file Bar8.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_21_Pro.mp4...
# CSV file Bar9.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_27_Pro.mp4...
# CSV file Bar10.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_31_Pro.mp4...
# CSV file Bar11.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_36_Pro.mp4...
# CSV file Bar12.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_45_58_Pro.mp4...
# CSV file Bar13.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_46_03_Pro.mp4...
# CSV file Bar14.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_46_08_Pro.mp4...
# CSV file Bar15.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_46_13_Pro.mp4...
# CSV file Bar16.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_46_19_Pro.mp4...
# CSV file Bar17.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_46_24_Pro.mp4...
# CSV file Bar18.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_46_29_Pro.mp4...
# CSV file Bar19.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_49_25_Pro.mp4...
# CSV file Bar20.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_49_32_Pro.mp4...
# CSV file Bar21.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_49_37_Pro.mp4...
# CSV file Bar22.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_49_43_Pro.mp4...
# CSV file Bar23.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_49_49_Pro.mp4...
# CSV file Bar24.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_49_55_Pro.mp4...
# CSV file Bar25.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_50_01_Pro.mp4...
# CSV file Bar26.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_50_27_Pro.mp4...
# CSV file Bar27.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_50_32_Pro.mp4...
# CSV file Bar28.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_50_37_Pro.mp4...
# CSV file Bar29.csv created in ./SignsCsv/Bar.
# Processing ./myHero/Bar\WIN_20241112_17_50_42_Pro.mp4...
# CSV file Bar30.csv created in ./SignsCsv/Bar.
# Finished processing folder: Bar
# Processing ./myHero/Bhok\WIN_20241112_16_53_42_Pro.mp4...
# CSV file Bhok1.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_53_48_Pro.mp4...
# CSV file Bhok2.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_53_54_Pro.mp4...
# CSV file Bhok3.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_00_Pro.mp4...
# CSV file Bhok4.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_06_Pro.mp4...
# CSV file Bhok5.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_12_Pro.mp4...
# CSV file Bhok6.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_18_Pro.mp4...
# CSV file Bhok7.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_23_Pro.mp4...
# CSV file Bhok8.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_30_Pro.mp4...
# CSV file Bhok9.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_35_Pro.mp4...
# CSV file Bhok10.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_41_Pro.mp4...
# CSV file Bhok11.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_54_53_Pro.mp4...
# CSV file Bhok12.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_15_Pro.mp4...
# CSV file Bhok13.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_23_Pro.mp4...
# CSV file Bhok14.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_28_Pro.mp4...
# CSV file Bhok15.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_32_Pro.mp4...
# CSV file Bhok16.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_42_Pro.mp4...
# CSV file Bhok17.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_48_Pro.mp4...
# CSV file Bhok18.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_53_Pro.mp4...
# CSV file Bhok19.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_55_59_Pro.mp4...
# CSV file Bhok20.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_56_09_Pro.mp4...
# CSV file Bhok21.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_56_14_Pro.mp4...
# CSV file Bhok22.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_56_20_Pro.mp4...
# CSV file Bhok23.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_56_25_Pro.mp4...
# CSV file Bhok24.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_56_31_Pro.mp4...
# CSV file Bhok25.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_56_37_Pro.mp4...
# CSV file Bhok26.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_56_43_Pro.mp4...
# CSV file Bhok27.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_57_18_Pro.mp4...
# CSV file Bhok28.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_57_24_Pro.mp4...
# CSV file Bhok29.csv created in ./SignsCsv/Bhok.
# Processing ./myHero/Bhok\WIN_20241112_16_57_33_Pro.mp4...
# CSV file Bhok30.csv created in ./SignsCsv/Bhok.
# Finished processing folder: Bhok
# Processing ./myHero/Dikka\WIN_20241112_17_36_00_Pro.mp4...
# CSV file Dikka1.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_36_08_Pro.mp4...
# CSV file Dikka2.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_36_13_Pro.mp4...
# CSV file Dikka3.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_36_19_Pro.mp4...
# CSV file Dikka4.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_38_20_Pro.mp4...
# CSV file Dikka5.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_38_32_Pro.mp4...
# CSV file Dikka6.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_38_56_Pro.mp4...
# CSV file Dikka7.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_39_09_Pro.mp4...
# CSV file Dikka8.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_39_15_Pro.mp4...
# CSV file Dikka9.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_39_22_Pro.mp4...
# CSV file Dikka10.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_39_30_Pro.mp4...
# CSV file Dikka11.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_39_35_Pro.mp4...
# CSV file Dikka12.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_39_41_Pro.mp4...
# CSV file Dikka13.csv created in ./SignsCsv/Dikka.
# Processing ./myHero/Dikka\WIN_20241112_17_39_47_Pro.mp4...
# CSV file Dikka14.csv created in ./SignsCsv/Dikka.
# Finished processing folder: Dikka
# Processing ./myHero/Dukhi\WIN_20241112_17_27_43_Pro.mp4...
# CSV file Dukhi1.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_27_49_Pro.mp4...
# CSV file Dukhi2.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_27_54_Pro.mp4...
# CSV file Dukhi3.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_00_Pro.mp4...
# CSV file Dukhi4.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_06_Pro.mp4...
# CSV file Dukhi5.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_12_Pro.mp4...
# CSV file Dukhi6.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_18_Pro.mp4...
# CSV file Dukhi7.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_24_Pro.mp4...
# CSV file Dukhi8.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_31_Pro.mp4...
# CSV file Dukhi9.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_37_Pro.mp4...
# CSV file Dukhi10.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_43_Pro.mp4...
# CSV file Dukhi11.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_49_Pro.mp4...
# CSV file Dukhi12.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_28_54_Pro.mp4...
# CSV file Dukhi13.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_00_Pro.mp4...
# CSV file Dukhi14.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_05_Pro.mp4...
# CSV file Dukhi15.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_11_Pro.mp4...
# CSV file Dukhi16.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_17_Pro.mp4...
# CSV file Dukhi17.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_23_Pro.mp4...
# CSV file Dukhi18.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_29_Pro.mp4...
# CSV file Dukhi19.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_34_Pro.mp4...
# CSV file Dukhi20.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_40_Pro.mp4...
# CSV file Dukhi21.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_46_Pro.mp4...
# CSV file Dukhi22.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_50_Pro.mp4...
# CSV file Dukhi23.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_29_56_Pro.mp4...
# CSV file Dukhi24.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_30_02_Pro.mp4...
# CSV file Dukhi25.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_30_08_Pro.mp4...
# CSV file Dukhi26.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_30_28_Pro.mp4...
# CSV file Dukhi27.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_30_34_Pro.mp4...
# CSV file Dukhi28.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_30_40_Pro.mp4...
# CSV file Dukhi29.csv created in ./SignsCsv/Dukhi.
# Processing ./myHero/Dukhi\WIN_20241112_17_31_09_Pro.mp4...
# CSV file Dukhi30.csv created in ./SignsCsv/Dukhi.
# Finished processing folder: Dukhi
# Processing ./myHero/Eklopan\WIN_20241112_17_16_31_Pro.mp4...
# CSV file Eklopan1.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_10_Pro.mp4...
# CSV file Eklopan2.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_19_Pro.mp4...
# CSV file Eklopan3.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_25_Pro.mp4...
# CSV file Eklopan4.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_31_Pro.mp4...
# CSV file Eklopan5.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_37_Pro.mp4...
# CSV file Eklopan6.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_46_Pro.mp4...
# CSV file Eklopan7.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_51_Pro.mp4...
# CSV file Eklopan8.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_19_56_Pro.mp4...
# CSV file Eklopan9.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_20_03_Pro.mp4...
# CSV file Eklopan10.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_20_09_Pro.mp4...
# CSV file Eklopan11.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_20_15_Pro.mp4...
# CSV file Eklopan12.csv created in ./SignsCsv/Eklopan.
# Processing ./myHero/Eklopan\WIN_20241112_17_20_21_Pro.mp4...
# CSV file Eklopan13.csv created in ./SignsCsv/Eklopan.
# Finished processing folder: Eklopan
# Processing completed.
